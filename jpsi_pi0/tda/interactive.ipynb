# %%
import tda
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %%
reload(tda)
tda.plot(0,1)
tda.plot(0,2)
tda.plot(0,3)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %%
reload(tda)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.135
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %% [markdown]
# * Limits set by $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>\*</sup><sub>$\pi^0$</sub>)=1</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>*</sup><sub>$\pi^0$</sub>)=0</sub>

# %%
reload(tda)
tda.integrate(1,0)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# xsect(s= 12.26, -0.45 < Delta^2 < 0.60)= 136.82
# xsect(s= 16.87, -2.76 < Delta^2 < 0.46)= 218.19
# xsect(s= 24.35, -6.50 < Delta^2 < 0.32)= 225.85

# %% [markdown]
# * Below, limits set by $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>= -0.5</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>=0</sub>

# %%
reload(tda)
tda.integrate(1,1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# xsect(s= 12.26, -1.23 < Delta^2 < 0.65)= 194.04
# xsect(s= 16.87, -0.60 < Delta^2 < 0.47)= 129.84
# xsect(s= 24.35, -0.47 < Delta^2 < 0.33)= 77.74

# %%
reload(tda)
tda.plot(0,2)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %%
reload(tda)
tda.plot_xsect_int()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [[[-0.3, -0.21], [-0.21, -0.12], [-0.12, -0.030000000000000027], [-0.030000000000000027, 0.06], [0.06, 0.15000000000000002], [0.15000000000000002, 0.23999999999999994], [0.23999999999999994, 0.3299999999999999], [0.3299999999999999, 0.42], [0.42, 0.51], [0.51, 0.6000000000000001]], [[-1.0, -0.854], [-0.854, -0.708], [-0.708, -0.562], [-0.562, -0.41600000000000004], [-0.41600000000000004, -0.27], [-0.27, -0.124], [-0.124, 0.021999999999999797], [0.021999999999999797, 0.16799999999999993], [0.16799999999999993, 0.31400000000000006], [0.31400000000000006, 0.45999999999999996]], [[-1.0, -0.868], [-0.868, -0.736], [-0.736, -0.604], [-0.604, -0.472], [-0.472, -0.33999999999999997], [-0.33999999999999997, -0.20799999999999996], [-0.20799999999999996, -0.07599999999999996], [-0.07599999999999996, 0.05600000000000005], [0.05600000000000005, 0.18800000000000017], [0.18800000000000017, 0.32000000000000006]]]
# plab= 12.26, sig_tot(-0.30<Delta^2<-0.21) = 6.99 pm 0.00
# plab= 12.26, sig_tot(-0.21<Delta^2<-0.12) = 7.59 pm 0.00
# plab= 12.26, sig_tot(-0.12<Delta^2<-0.03) = 8.30 pm 0.00
# plab= 12.26, sig_tot(-0.03<Delta^2<0.06) = 9.17 pm 0.00
# plab= 12.26, sig_tot(0.06<Delta^2<0.15) = 10.23 pm 0.00
# plab= 12.26, sig_tot(0.15<Delta^2<0.24) = 11.57 pm 0.00
# plab= 12.26, sig_tot(0.24<Delta^2<0.33) = 13.31 pm 0.00
# plab= 12.26, sig_tot(0.33<Delta^2<0.42) = 15.68 pm 0.00
# plab= 12.26, sig_tot(0.42<Delta^2<0.51) = 19.08 pm 0.00
# plab= 12.26, sig_tot(0.51<Delta^2<0.60) = 24.36 pm 0.00
# plab= 16.87, sig_tot(-1.00<Delta^2<-0.85) = 8.18 pm 0.00
# plab= 16.87, sig_tot(-0.85<Delta^2<-0.71) = 8.90 pm 0.00
# plab= 16.87, sig_tot(-0.71<Delta^2<-0.56) = 9.76 pm 0.00
# plab= 16.87, sig_tot(-0.56<Delta^2<-0.42) = 10.80 pm 0.00
# plab= 16.87, sig_tot(-0.42<Delta^2<-0.27) = 12.08 pm 0.00
# plab= 16.87, sig_tot(-0.27<Delta^2<-0.12) = 13.72 pm 0.00
# plab= 16.87, sig_tot(-0.12<Delta^2<0.02) = 15.87 pm 0.00
# plab= 16.87, sig_tot(0.02<Delta^2<0.17) = 18.83 pm 0.00
# plab= 16.87, sig_tot(0.17<Delta^2<0.31) = 23.14 pm 0.00
# plab= 16.87, sig_tot(0.31<Delta^2<0.46) = 30.03 pm 0.00
# plab= 24.35, sig_tot(-1.00<Delta^2<-0.87) = 6.38 pm 0.00
# plab= 24.35, sig_tot(-0.87<Delta^2<-0.74) = 6.88 pm 0.00
# plab= 24.35, sig_tot(-0.74<Delta^2<-0.60) = 7.46 pm 0.00
# plab= 24.35, sig_tot(-0.60<Delta^2<-0.47) = 8.16 pm 0.00
# plab= 24.35, sig_tot(-0.47<Delta^2<-0.34) = 8.99 pm 0.00
# plab= 24.35, sig_tot(-0.34<Delta^2<-0.21) = 10.02 pm 0.00
# plab= 24.35, sig_tot(-0.21<Delta^2<-0.08) = 11.31 pm 0.00
# plab= 24.35, sig_tot(-0.08<Delta^2<0.06) = 12.99 pm 0.00
# plab= 24.35, sig_tot(0.06<Delta^2<0.19) = 15.25 pm 0.00
# plab= 24.35, sig_tot(0.19<Delta^2<0.32) = 18.47 pm 0.00

# %%
reload(tda)
tda.plot_mpi0_test(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=141.70 nevt(nr)=33667.08 xs(nr)=141.70 nevt(fr)=33667.08
# 1 16.8745
# s=16.87  xs(nr)=119.36 nevt(nr)=28359.66 xs(nr)=217.36 nevt(fr)=51644.95
# 2 24.346
# s=24.35  xs(nr)=78.13 nevt(nr)=18562.92 xs(nr)=225.00 nevt(fr)=53460.16

# %%
x = {7:70, 1:10, 4:40, 2:20, 6:60, 3:30}

x[2]
x[3]
x.keys()
for k in sort(x.keys()):
    print "%d -> %d" % (k, x[k])
# Out:
# 1 -> 10
# 2 -> 20
# 3 -> 30
# 4 -> 40
# 6 -> 60
# 7 -> 70

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=141.70 nevt(nr)=33667.08 xs(nr)=141.70 nevt(fr)=33667.08
# 1 16.8745
# s=16.87  xs(nr)=119.36 nevt(nr)=28359.66 xs(nr)=217.36 nevt(fr)=51644.95
# 2 24.346
# s=24.35  xs(nr)=78.13 nevt(nr)=18562.92 xs(nr)=225.00 nevt(fr)=53460.16

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=141.70 nevt(nr)=33667.08 xs(nr)=141.70 nevt(fr)=33667.08
# 1 16.8745
# s=16.87  xs(nr)=119.36 nevt(nr)=28359.66 xs(nr)=217.36 nevt(fr)=51644.95
# 2 24.346
# s=24.35  xs(nr)=78.13 nevt(nr)=18562.92 xs(nr)=225.00 nevt(fr)=53460.16
