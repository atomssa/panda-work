# %%
import tda
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.plot(0,1)
tda.plot(0,2)
tda.plot(0,3)
# Out:
# MN = 0.940
# Mpi0 = 0.135
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %% [markdown]
# * Limits set by $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>\*</sup><sub>$\pi^0$</sub>)=1</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>*</sup><sub>$\pi^0$</sub>)=0</sub>

# %%
reload(tda)
tda.integrate(1,0)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# xsect(s= 12.26, -0.30 < Delta^2 < 0.60)= 105.17
# xsect(s= 16.87, -0.45 < Delta^2 < 0.46)= 96.85
# xsect(s= 24.35, -0.45 < Delta^2 < 0.32)= 62.98

# %% [markdown]
# * Below, limits set by $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>= -0.5</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>=0</sub>

# %%
reload(tda)
tda.integrate(1,1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# xsect(s= 12.26, -1.23 < Delta^2 < 0.65)= 161.61
# xsect(s= 16.87, -0.60 < Delta^2 < 0.47)= 108.14
# xsect(s= 24.35, -0.47 < Delta^2 < 0.33)= 64.75

# %%
reload(tda)
tda.plot(0,2)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.plot_xsect_int()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [[[-0.3, -0.21], [-0.21, -0.12], [-0.12, -0.030000000000000027], [-0.030000000000000027, 0.06], [0.06, 0.15000000000000002], [0.15000000000000002, 0.23999999999999994], [0.23999999999999994, 0.3299999999999999], [0.3299999999999999, 0.42], [0.42, 0.51], [0.51, 0.6000000000000001]], [[-1.0, -0.854], [-0.854, -0.708], [-0.708, -0.562], [-0.562, -0.41600000000000004], [-0.41600000000000004, -0.27], [-0.27, -0.124], [-0.124, 0.021999999999999797], [0.021999999999999797, 0.16799999999999993], [0.16799999999999993, 0.31400000000000006], [0.31400000000000006, 0.45999999999999996]], [[-1.0, -0.868], [-0.868, -0.736], [-0.736, -0.604], [-0.604, -0.472], [-0.472, -0.33999999999999997], [-0.33999999999999997, -0.20799999999999996], [-0.20799999999999996, -0.07599999999999996], [-0.07599999999999996, 0.05600000000000005], [0.05600000000000005, 0.18800000000000017], [0.18800000000000017, 0.32000000000000006]]]
# plab= 12.26, sig_tot(-0.30<Delta^2<-0.21) = 5.82 pm 0.00
# plab= 12.26, sig_tot(-0.21<Delta^2<-0.12) = 6.32 pm 0.00
# plab= 12.26, sig_tot(-0.12<Delta^2<-0.03) = 6.92 pm 0.00
# plab= 12.26, sig_tot(-0.03<Delta^2<0.06) = 7.63 pm 0.00
# plab= 12.26, sig_tot(0.06<Delta^2<0.15) = 8.52 pm 0.00
# plab= 12.26, sig_tot(0.15<Delta^2<0.24) = 9.63 pm 0.00
# plab= 12.26, sig_tot(0.24<Delta^2<0.33) = 11.09 pm 0.00
# plab= 12.26, sig_tot(0.33<Delta^2<0.42) = 13.06 pm 0.00
# plab= 12.26, sig_tot(0.42<Delta^2<0.51) = 15.89 pm 0.00
# plab= 12.26, sig_tot(0.51<Delta^2<0.60) = 20.29 pm 0.00
# plab= 16.87, sig_tot(-1.00<Delta^2<-0.85) = 6.81 pm 0.00
# plab= 16.87, sig_tot(-0.85<Delta^2<-0.71) = 7.41 pm 0.00
# plab= 16.87, sig_tot(-0.71<Delta^2<-0.56) = 8.13 pm 0.00
# plab= 16.87, sig_tot(-0.56<Delta^2<-0.42) = 8.99 pm 0.00
# plab= 16.87, sig_tot(-0.42<Delta^2<-0.27) = 10.06 pm 0.00
# plab= 16.87, sig_tot(-0.27<Delta^2<-0.12) = 11.43 pm 0.00
# plab= 16.87, sig_tot(-0.12<Delta^2<0.02) = 13.22 pm 0.00
# plab= 16.87, sig_tot(0.02<Delta^2<0.17) = 15.68 pm 0.00
# plab= 16.87, sig_tot(0.17<Delta^2<0.31) = 19.27 pm 0.00
# plab= 16.87, sig_tot(0.31<Delta^2<0.46) = 25.01 pm 0.00
# plab= 24.35, sig_tot(-1.00<Delta^2<-0.87) = 5.31 pm 0.00
# plab= 24.35, sig_tot(-0.87<Delta^2<-0.74) = 5.73 pm 0.00
# plab= 24.35, sig_tot(-0.74<Delta^2<-0.60) = 6.22 pm 0.00
# plab= 24.35, sig_tot(-0.60<Delta^2<-0.47) = 6.79 pm 0.00
# plab= 24.35, sig_tot(-0.47<Delta^2<-0.34) = 7.49 pm 0.00
# plab= 24.35, sig_tot(-0.34<Delta^2<-0.21) = 8.35 pm 0.00
# plab= 24.35, sig_tot(-0.21<Delta^2<-0.08) = 9.42 pm 0.00
# plab= 24.35, sig_tot(-0.08<Delta^2<0.06) = 10.82 pm 0.00
# plab= 24.35, sig_tot(0.06<Delta^2<0.19) = 12.70 pm 0.00
# plab= 24.35, sig_tot(0.19<Delta^2<0.32) = 15.39 pm 0.00

# %%
reload(tda)
tda.plot_mpi0_test(4)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=118.02 nevt(nr)=28040.38 xs(nr)=118.02 nevt(fr)=28040.38
# 1 16.8745
# s=16.87  xs(nr)=125.46 nevt(nr)=29809.92 xs(nr)=181.03 nevt(fr)=43013.66
# 2 24.346
# s=24.35  xs(nr)=87.63 nevt(nr)=20819.94 xs(nr)=187.40 nevt(fr)=44525.50

# %%
x = {7:70, 1:10, 4:40, 2:20, 6:60, 3:30}

x[2]
x[3]
x.keys()
for k in sort(x.keys()):
    print "%d -> %d" % (k, x[k])
# Out:
# 1 -> 10
# 2 -> 20
# 3 -> 30
# 4 -> 40
# 6 -> 60
# 7 -> 70

# %%
dict.keys?

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=118.02 nevt(nr)=28040.38 xs(nr)=118.02 nevt(fr)=28040.38
# 1 16.8745
# s=16.87  xs(nr)=125.46 nevt(nr)=29809.92 xs(nr)=181.03 nevt(fr)=43013.66
# 2 24.346
# s=24.35  xs(nr)=87.63 nevt(nr)=20819.94 xs(nr)=187.40 nevt(fr)=44525.50

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=118.02 nevt(nr)=28040.38 xs(nr)=118.02 nevt(fr)=28040.38
# 1 16.8745
# s=16.87  xs(nr)=99.41 nevt(nr)=23619.98 xs(nr)=181.03 nevt(fr)=43013.66
# 2 24.346
# s=24.35  xs(nr)=65.07 nevt(nr)=15460.54 xs(nr)=187.40 nevt(fr)=44525.50
