# %%
import tda
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Constants used in the plotting functions

# %%
reload(tda)
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# <module 'tda' from 'tda.py'>

# %% [markdown]
# ### $\xi$ range for the various setups

# %%
reload(tda)
tda.plot_xi()
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %% [markdown]
# ### Continuum background rate estimation
# #### Source: Mainz paper on $\pi$-N TDAs in $\bar{p}+p\rightarrow\pi^0e^+e^-$: _Eur. Phys. J. A (2015) 51: 107_
# - The integeral of the $e^+e^-$ background x-xect in any given $Q^2$ range, at any given energy based on Eq. 20 from reference above.
# - The minimum and maximum theta angles ($cos(\theta_{min})$ and $\cos(\theta_{max})$) at a given value of $s$ based on the $t$ validity range at that energy
# - The S/B ratio with S=$\pi^0J/\psi$ and B=$\pi^0e^+e^-$

# %%
#reload(tda)
#a=tda.sig_tot_epem(3.0,4.3,5.0)
#b=tda.sig_tot_epem(5.0,9.0,10.0)
#print "a/b=%f, ans=%f"%(a/b,1675/233)
#a0=tda.sig_tot_epem(2.96, 3.22, 12.25)
#a1=tda.sig_tot_epem(2.96, 3.22, 16.87)
#a2=tda.sig_tot_epem(2.96, 3.22, 24.35)
#br = 0.06
#print "%f, %f, %f" % (206800*br/a0, 309600*br/a1, 316300*br/a2)
tda.sig_tot_epem(pow(2.9,2), pow(3.3,2), 12.25)
tda.sig_tot_epem(pow(2.9,2), pow(3.3,2), 16.87)
tda.sig_tot_epem(pow(2.9,2), pow(3.3,2), 24.35)
# Out:
# xsect_d1= 1675.000000
# xsect_d2= 220.273771
# s=12.26 dt=0.682, ct_min=0.32, ct_max=0.93 xsect=  13.6 stob=903.4
# s=16.87 dt=1.730, ct_min=0.45, ct_max=0.99 xsect=  21.6 stob=852.3
# s=24.35 dt=3.150, ct_min=0.53, ct_max=1.00 xsect=  24.8 stob=756.2
# xsect_d1= 1675.000000
# xsect_d2= 220.273771
# s=12.26 dt=0.682, ct_min=0.32, ct_max=0.93 xsect=  13.6 stob=903.4
# s=16.87 dt=1.730, ct_min=0.45, ct_max=0.99 xsect=  21.6 stob=852.3
# s=24.35 dt=3.150, ct_min=0.53, ct_max=1.00 xsect=  24.8 stob=756.2
# xsect_d1= 1675.000000
# xsect_d2= 220.273771
# s=12.26 dt=0.682, ct_min=0.32, ct_max=0.93 xsect=  13.6 stob=903.4
# s=16.87 dt=1.730, ct_min=0.45, ct_max=0.99 xsect=  21.6 stob=852.3
# s=24.35 dt=3.150, ct_min=0.53, ct_max=1.00 xsect=  24.8 stob=756.2
# 26.908987324859634

# %% [markdown]
# ### Plot differential cross-section as a function of $\Delta_T^2$ or $s$
# #### Source: $\pi$-N TDA paper from $\bar{p}+p\rightarrow\pi^0+J/\psi$: _Phys. Lett. B, 724(1–3):99 – 107, 2013_
# - Argument #1: whether to plot $\Delta_T^2$ dependence or $s$ dependence of the x-sect at $\Delta_T^2$
# - Argument #2 (Used only if arg1==0): Selection of energies to plot (0->s=10,12.26,15,16.87,24.35; 1->s=12.26,16.87,24.35; 2->s=10,15)

# %%
reload(tda)
tda.plot(0,1)
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04

# %%
tda.plot(1)

# %% [markdown]
# ### Funciton for plotting the integrated cross-section as a function of $\sqrt{s}$
# #### Source: _Phys. Lett. B, 724(1–3):99 – 107, 2013_

# %% [markdown]
# ### Limits set by $\left.\Delta^2\right|_{\cos{\theta^*_{\pi^0}}=1} < \Delta^2 < \left.\Delta^2\right|_{\cos{\theta^*_{\pi^0}}=0}$

# %%
reload(tda)
tda.integrate(1,0)
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# xsect(s= 12.25, -0.09 < Delta^2 < 0.59)= 103.20
# xsect(s= 16.87, -1.30 < Delta^2 < 0.43)= 154.79
# xsect(s= 24.35, -2.85 < Delta^2 < 0.30)= 158.14

# %% [markdown]
# ### Limits set by $\left.\Delta^2\right|_{\cos{\theta^*_{\pi^0}}=-0.5} < \Delta^2 < \left.\Delta^2\right|_{\cos{\theta^*_{\pi^0}}=0}$

# %%
tda.integrate(1,1)
# Out:
# xsect(s= 12.25, -1.24 < Delta^2 < 0.65)= 188.13
# xsect(s= 16.87, -0.60 < Delta^2 < 0.47)= 125.90
# xsect(s= 24.35, -0.47 < Delta^2 < 0.33)= 75.45

# %%
tda.plot(0,2)
tda.plot(1)

# %% [markdown]
# ### The interated cross section in a binning of the $t$ (or $u$) axis

# %%
tda.plot_xsect_int()

# %% [markdown]
# ### Investigation of the effect of pi0 mass assumptions on the cross-seciton vs $\Delta_T^2$
# #### How different the x-sect becomes if we used a different value for $m_{\pi^0}$ than the PDG value?

# %%
tda.plot_mpi0_test(1)

# %% [markdown]
# ### Function to calculate the number of events to expect for each energy within
# - The validity range of the TDA model (nr)
# - The whole kinematically allowed space (fr)

# %%
reload(tda)
tda.numevt(msv=False)
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=206.75 nevt(nr)=24561.88 xs(fr)=275.92 nevt(fr)=32779.32
# 1 16.8745
# s=16.87  xs(nr)=280.53 nevt(nr)=33327.48 xs(fr)=422.07 nevt(fr)=50142.17
# 2 24.346
# s=24.35  xs(nr)=199.86 nevt(nr)=23742.89 xs(fr)=436.54 nevt(fr)=51860.49

# %%
reload(tda)
tda.numevt(msv=True)
# Out:
# MN = 0.938
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.356e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=206.75 nevt(nr)=1172.83 xs(fr)=275.92 nevt(fr)=1565.21
# 1 16.8745
# s=16.87  xs(nr)=280.53 nevt(nr)=1716.37 xs(fr)=422.07 nevt(fr)=2582.32
# 2 24.346
# s=24.35  xs(nr)=199.86 nevt(nr)=1282.12 xs(fr)=436.54 nevt(fr)=2800.47

# %%
sqrt(2.*32779.32/1565.27)
# Out:
# 6.4717292065664402

# %%
1565.27/32779.32
# Out:
# 0.04775175323954249
