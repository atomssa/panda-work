# %%
import tda

# %%
reload(tda)
tda.plot(0,1)
tda.plot(0,2)
tda.plot(0,3)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %% [markdown]
# * Limits set by $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>\*</sup><sub>$\pi^0$</sub>)=1</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>*</sup><sub>$\pi^0$</sub>)=0</sub>

# %%
reload(tda)
tda.integrate(1,0)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# xsect(s= 12.26, -0.45 < Delta^2 < 0.60)= 117.66
# xsect(s= 16.87, -2.76 < Delta^2 < 0.46)= 187.65
# xsect(s= 24.35, -6.50 < Delta^2 < 0.32)= 194.23

# %% [markdown]
# * Below, limits set by $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>= -0.5</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>=0</sub>

# %%
reload(tda)
tda.integrate(1,1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# xsect(s= 12.26, -1.23 < Delta^2 < 0.65)= 166.88
# xsect(s= 16.87, -0.60 < Delta^2 < 0.47)= 111.66
# xsect(s= 24.35, -0.47 < Delta^2 < 0.33)= 66.85

# %%
reload(tda)
tda.plot(0,2)
tda.plot(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.plot_xsect_int()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# ...

# %%
reload(tda)
tda.plot_mpi0_test(1)
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=121.86 nevt(nr)=28953.62 xs(nr)=121.86 nevt(fr)=28953.62
# 1 16.8745
# s=16.87  xs(nr)=102.65 nevt(nr)=24389.25 xs(nr)=186.93 nevt(fr)=44414.56
# 2 24.346
# s=24.35  xs(nr)=67.19 nevt(nr)=15964.07 xs(nr)=193.50 nevt(fr)=45975.63

# %%
x = {7:70, 1:10, 4:40, 2:20, 6:60, 3:30}

x[2]
x[3]
x.keys()
for k in sort(x.keys()):
    print "%d -> %d" % (k, x[k])
# Out:
# 1 -> 10
# 2 -> 20
# 3 -> 30
# 4 -> 40
# 6 -> 60
# 7 -> 70

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=121.86 nevt(nr)=28953.62 xs(nr)=121.86 nevt(fr)=28953.62
# 1 16.8745
# s=16.87  xs(nr)=102.65 nevt(nr)=24389.25 xs(nr)=186.93 nevt(fr)=44414.56
# 2 24.346
# s=24.35  xs(nr)=67.19 nevt(nr)=15964.07 xs(nr)=193.50 nevt(fr)=45975.63

# %%
reload(tda)
tda.numevt()
# Out:
# MN = 0.940
# Mpi0 = 0.000
# fpi = 0.093
# fpsi = 0.383
# fN = 0.005
# gpiNN = 13.210
# alpha_s = 0.252
# Mbar = 3.000
# M0 = 8776.880
# C = 4.039e-04
# [12.2649, 16.8745, 24.346]
# 0 12.2649
# s=12.26  xs(nr)=121.86 nevt(nr)=28953.62 xs(nr)=121.86 nevt(fr)=28953.62
# 1 16.8745
# s=16.87  xs(nr)=102.65 nevt(nr)=24389.25 xs(nr)=186.93 nevt(fr)=44414.56
# 2 24.346
# s=24.35  xs(nr)=67.19 nevt(nr)=15964.07 xs(nr)=193.50 nevt(fr)=45975.63

# %%
(225.0e-12*0.06)/(0.2e-3)
# Out:
# 6.749999999999999e-08
