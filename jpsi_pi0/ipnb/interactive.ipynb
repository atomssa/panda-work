# %%
import tda

# %%
reload(tda)
tda.plot(0,1)
tda.plot(0,2)
tda.plot(0,3)
# Out:
# M0 = 8776.88

# %%
reload(tda)
tda.plot(1)
# Out:
# M0 = 8776.88

# %% [markdown]
# * Limits set by $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>\*</sup><sub>$\pi^0$</sub>)=1</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>cos($\theta$<sup>*</sup><sub>$\pi^0$</sub>)=0</sub>

# %%
reload(tda)
tda.integrate(1,0)
# Out:
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.250
# Mbar = 2.300
# M0 = 8776.880
# C = 4.250e-04
# xsect(s= 12.26, -0.45 < Delta^2 < 0.61)= 52211111.17
# xsect(s= 16.87, -2.76 < Delta^2 < 0.46)= 56892871.69
# xsect(s= 24.35, -6.50 < Delta^2 < 0.32)= 49909859.68

# %% [markdown]
# * Below, limits set by $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>= -0.5</sub> < $\Delta$<sup>2</sup> < $\Delta$<sup>2</sup>|<sub>$\Delta$<sub>T</sub><sup>2</sup>=0</sub>

# %%
reload(tda)
tda.integrate(1,1)
# Out:
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.250
# Mbar = 2.300
# M0 = 8776.880
# C = 4.250e-04
# xsect(s= 12.26, -0.51 < Delta^2 < 0.37)= 32921719.08
# xsect(s= 16.87, -0.46 < Delta^2 < 0.27)= 20614892.61
# xsect(s= 24.35, -0.45 < Delta^2 < 0.19)= 12606276.63

# %%
reload(tda)
tda.plot(0,2)
tda.plot(1)
# Out:
# fpi = 0.093
# fpsi = 0.413
# fN = 0.005
# gpiNN = 13.000
# alpha_s = 0.250
# Mbar = 3.000
# M0 = 8776.880
# C = 4.250e-04
